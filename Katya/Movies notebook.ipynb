# %% [markdown]
# # IMdB Movies

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from random import gauss, seed
from scipy import stats
import seaborn as sns
from mpl_toolkits import mplot3d
import sklearn.metrics as metrics
import statsmodels.api as sm
import warnings
import sqlite3
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ## Load datasets

# %%
movie_budgets = pd.read_csv('../zippedData/tn.movie_budgets.csv.gz')
movies = pd.read_csv('../zippedData/tmdb.movies.csv.gz')
reviews = pd.read_csv('../zippedData/rt.reviews.tsv.gz', sep = '\t', encoding = 'latin1')
movie_info = pd.read_csv('../zippedData/rt.movie_info.tsv.gz', sep = '\t', encoding = 'latin1')
movie_gross = pd.read_csv('../zippedData/bom.movie_gross.csv.gz')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Cleaning Movie Budgets Dataset

# %%
# Cleaning and Formatting the 'production_budget' Column in the 'movie_budgets' DataFrame
movie_budgets['production_budget'] = movie_budgets['production_budget'].map(lambda x: x.replace("$", "").replace(",", ""))
movie_budgets['production_budget'] = movie_budgets['production_budget'].map(lambda x: float(x))

# %%
# Cleaning and Formatting the 'domestic_gross' Column in the 'movie_budgets' DataFrame
movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].map(lambda x: x.replace("$", "").replace(",", ""))
movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].map(lambda x: float(x))

# %%
# Cleaning and Formatting the 'worldwide_gross' Column in the 'movie_budgets' DataFrame
movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].map(lambda x: x.replace("$", "").replace(",", ""))
movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].map(lambda x: float(x))

# %%
# Converting 'release_date' to datetime formatmovie_budgets
movie_budgets['release_date'] = pd.to_datetime(movie_budgets['release_date'], format='%b %d, %Y')

# %%
# Calculating ROI for Movies
movie_budgets['ROI'] = ((movie_budgets['worldwide_gross'] - movie_budgets['production_budget'])/movie_budgets['production_budget'])

# %% [markdown]
# ### Cleaning Movie Info Dataset

# %%
# Creating Genre Lists from Genre Column in Movie Info DataFrame
movie_info['genre'] = movie_info['genre'].apply(lambda x: str(x))
movie_info['genre_list'] = movie_info['genre'].apply(lambda x: x.split('|'))

# %%
movie_info.drop('genre', axis=1, inplace=True)

# %%
# Converting Theater Date Column to Datetime in Movie Info DataFrame
movie_info['theater_date'] = pd.to_datetime(movie_info['theater_date'], format='%b %d, %Y')

# %%
# Cleaning and Converting Runtime Column in Movie Info DataFrame
movie_info['runtime'] = movie_info['runtime'].str.replace("minutes", "")
movie_info['runtime'] = movie_info['runtime'].map(lambda x: float(x))

# %%
# Converting Columns to Strings in Movie Info DataFrame
movie_info['director'] = movie_info['director'].map(lambda x: str(x))
movie_info['studio'] = movie_info['studio'].map(lambda x: str(x))

# %%
# Cleaning Box Office Column in Movie Info DataFrame
movie_info['box_office'] = movie_info['box_office'].str.replace('$', '')
movie_info['box_office'] = movie_info['box_office'].str.replace(',', '')

# %%
movie_info['box_office'] = movie_info['box_office'].map(lambda x: float(x))

# %%
# Dropping Rows with Missing Box Office Data in Movie Info DataFrame
movie_info.dropna(subset=['box_office'], inplace=True)

# %% [markdown]
# ## SQL Data Calling

# %% [markdown]
# ### Connecting to SQLite Database

# %%
con = sqlite3.connect('../zippedData/im.db')

# %% [markdown]
# ### Fetching Database Schema Information

# %%
master = pd.read_sql("""
SELECT *
FROM sqlite_master
;""", con)
master
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
tables = list(master['name'])
tables
# Out:
# ['movie_basics',
#  'directors',
#  'known_for',
#  'movie_akas',
#  'movie_ratings',
#  'persons',
#  'principals',
#  'writers']

# %%
movie_basics = pd.read_sql("""
SELECT *
FROM movie_basics
;""", con)
movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
directors = pd.read_sql("""
SELECT *
FROM directors
;""", con)

# %%
known_for = pd.read_sql("""
SELECT *
FROM known_for
;""", con)

# %%
movie_akas = pd.read_sql("""
SELECT *
FROM movie_akas
;""", con)
movie_akas
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg         None         None                0.0
# 1          None  imdbDisplay         None                0.0
# 2          None  imdbDisplay         None                0.0
# 3          None         None  short title                0.0
# 4          None  imdbDisplay         None                0.0
# ...         ...          ...          ...                ...
# 331698     None     original         None                1.0
# 331699       en  imdbDisplay         None                0.0
# 331700     None     original         None                1.0
# 331701     None         None         None                0.0
# 331702       en  imdbDisplay         None                0.0
#
# [331703 rows x 8 columns]

# %%
movie_ratings = pd.read_sql("""
SELECT *
FROM movie_ratings
;""", con)
movie_ratings
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
persons = pd.read_sql("""
SELECT *
FROM persons
;""", con)
persons
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
# [606648 rows x 5 columns]

# %%
principals = pd.read_sql("""
SELECT *
FROM principals
;""", con)
principals
# Out:
#           movie_id  ordering   person_id  category       job  \
# 0        tt0111414         1   nm0246005     actor      None
# 1        tt0111414         2   nm0398271  director      None
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor      None
# 4        tt0323808         1   nm3579312   actress      None
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor      None
# 1028182  tt9692684         2   nm4929530      self      None
# 1028183  tt9692684         3  nm10441594  director      None
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                        None
# 2                        None
# 3                        None
# 4            ["Beth Boothby"]
# ...                       ...
# 1028181  ["Ebenezer Scrooge"]
# 1028182   ["Herself","Regan"]
# 1028183                  None
# 1028184                  None
# 1028185                  None
#
# [1028186 rows x 6 columns]

# %%
writers = pd.read_sql("""
SELECT *
FROM writers
;""", con)
writers
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0438973   nm0175726
# 2       tt0438973   nm1802864
# 3       tt0462036   nm1940585
# 4       tt0835418   nm0310087
# ...           ...         ...
# 255868  tt8999892  nm10122246
# 255869  tt8999974  nm10122357
# 255870  tt9001390   nm6711477
# 255871  tt9004986   nm4993825
# 255872  tt9010172   nm8352242
#
# [255873 rows x 2 columns]

# %% [markdown]
# ### Merging Datasets

# %%
# Merging Data from Multiple Tables in the SQLite Database
merged_sql = pd.read_sql("""
SELECT b.primary_title, b.runtime_minutes AS runtime, b.genres AS genres, 
r.averagerating, r.numvotes, p.category AS staff_role, ps.primary_name AS staff_name
FROM movie_basics AS b
JOIN movie_ratings AS r
    USING(movie_id)
JOIN principals AS p
    USING(movie_id)
JOIN persons AS ps
    USING(person_id)
;""", con)
merged_sql
# Out:
#        primary_title  runtime              genres  averagerating  numvotes  \
# 0          Sunghursh    175.0  Action,Crime,Drama            7.0        77
# 1          Sunghursh    175.0  Action,Crime,Drama            7.0        77
# 2          Sunghursh    175.0  Action,Crime,Drama            7.0        77
# 3          Sunghursh    175.0  Action,Crime,Drama            7.0        77
# 4          Sunghursh    175.0  Action,Crime,Drama            7.0        77
# ...              ...      ...                 ...            ...       ...
# 629593    Drømmeland     72.0         Documentary            6.5        11
# 629594    Drømmeland     72.0         Documentary            6.5        11
# 629595    Drømmeland     72.0         Documentary            6.5        11
# 629596    Drømmeland     72.0         Documentary            6.5        11
# 629597    Drømmeland     72.0         Documentary            6.5        11
#
#              staff_role          staff_name
# 0              composer             Naushad
# 1                writer          Abrar Alvi
# 2                writer              Gulzar
# 3                 actor         Dilip Kumar
# 4                 actor       Sanjeev Kumar
# ...                 ...                 ...
# 629593           editor       Tom Denoyette
# 629594         composer      Tobias Borkert
# 629595         director  Joost van der Wiel
# 629596             self         Nils Leidal
# 629597  cinematographer   Rogier Timmermans
#
# [629598 rows x 7 columns]

# %%
# Splitting the 'Genres' Column into Lists of Genres in the Merged DataFrame
merged_sql['genres'] = merged_sql['genres'].str.split(',')

# %%
# Merging Movie Budgets and Genres DataFrames on Movie Titles (Inner Join)
movies_budget_genres = pd.merge(movie_budgets, merged_sql, left_on='movie', right_on = 'primary_title', how='inner')

# %%
# Merging Movie Budgets and Movie Details DataFrames on Movie Titles (Inner Join)
movies_budget_merge = pd.merge(movie_budgets, movies, left_on='movie', right_on = 'original_title', how='inner')

# %%
movies_budget_merge.drop(['id_x', 'release_date_x'], axis = 1, inplace = True)

# %%
# Renaming Columns in Merged Movie Budgets and Movie Details DataFrame
movies_budget_merge.rename(columns={'id_y': 'id', 'release_date_y': 'release_date'}, inplace=True)
movies_budget_merge
# Out:
#                                             movie  production_budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# ...                                           ...                ...
# 2311                                       Exeter            25000.0
# 2312                                          Ten            25000.0
# 2313                                    Dry Spell            22000.0
# 2314                     All Superheroes Must Die            20000.0
# 2315                                    Newlyweds             9000.0
#
#       domestic_gross  worldwide_gross        ROI  Unnamed: 0  \
# 0        760507625.0     2.776345e+09   5.532577           6
# 1        241063875.0     1.045664e+09   1.546673        2470
# 2        459005868.0     1.403014e+09   3.243841       14169
# 3        678815482.0     2.048134e+09   5.827114       23811
# 4        229024295.0     6.559452e+08   1.186484       20623
# ...              ...              ...        ...         ...
# 2311             0.0     4.897920e+05  18.591680       14678
# 2312             0.0     0.000000e+00  -1.000000       12326
# 2313             0.0     0.000000e+00  -1.000000       10470
# 2314             0.0     0.000000e+00  -1.000000        8893
# 2315          4584.0     4.584000e+03  -0.490667        3468
#
#                genre_ids      id original_language  \
# 0      [28, 12, 14, 878]   19995                en
# 1           [12, 28, 14]    1865                en
# 2          [28, 12, 878]   99861                en
# 3           [12, 28, 14]  299536                en
# 4      [28, 12, 14, 878]  141052                en
# ...                  ...     ...               ...
# 2311            [53, 27]  226458                en
# 2312  [12, 27, 9648, 53]  279516                en
# 2313         [35, 10749]  255266                en
# 2314           [878, 53]   86304                en
# 2315         [35, 10749]   72766                en
#
#                                    original_title  popularity release_date  \
# 0                                          Avatar      26.526   2009-12-18
# 1     Pirates of the Caribbean: On Stranger Tides      30.579   2011-05-20
# 2                         Avengers: Age of Ultron      44.383   2015-05-01
# 3                          Avengers: Infinity War      80.773   2018-04-27
# 4                                  Justice League      34.953   2017-11-17
# ...                                           ...         ...          ...
# 2311                                       Exeter       5.934   2015-03-26
# 2312                                          Ten       1.575   2014-03-28
# 2313                                    Dry Spell       0.600   2013-02-14
# 2314                     All Superheroes Must Die       2.078   2013-01-04
# 2315                                    Newlyweds       1.973   2011-12-26
#
#                                             title  vote_average  vote_count
# 0                                          Avatar           7.4       18676
# 1     Pirates of the Caribbean: On Stranger Tides           6.4        8571
# 2                         Avengers: Age of Ultron           7.3       13457
# 3                          Avengers: Infinity War           8.3       13948
# 4                                  Justice League           6.2        7510
# ...                                           ...           ...         ...
# 2311                                       Exeter           4.7         121
# 2312                                          Ten           5.4           5
# 2313                                    Dry Spell           6.0           1
# 2314                     All Superheroes Must Die           3.9          19
# 2315                                    Newlyweds           5.4           7
#
# [2316 rows x 15 columns]

# %%
movies_budget_merge['original_language'].value_counts()
# Out:
# original_language
# en    2238
# fr      18
# es      13
# de       8
# pt       5
# hi       4
# sv       4
# it       2
# ar       2
# fi       2
# da       2
# ko       2
# et       2
# gu       1
# th       1
# ja       1
# tl       1
# no       1
# te       1
# nb       1
# xx       1
# pl       1
# hu       1
# ur       1
# tr       1
# id       1
# fa       1
# Name: count, dtype: int64

# %%
movies_budget_merge = movies_budget_merge.sort_values(by = 'ROI', ascending = False)
movies_budget_merge
# Out:
#                          movie  production_budget  domestic_gross  \
# 2276               The Gallows           100000.0      22764410.0
# 1816  Night of the Living Dead           114000.0      12087064.0
# 1280                 Halloween           325000.0      47000000.0
# 2107          The Devil Inside          1000000.0      53262945.0
# 1489     The Birth of a Nation           110000.0      10000000.0
# ...                        ...                ...             ...
# 2039                  Deadline          1800000.0             0.0
# 2040                  Deadline          1800000.0             0.0
# 2041     Dysfunctional Friends          1800000.0             0.0
# 2042    Independence Daysaster          1800000.0             0.0
# 1941               Close Range          3000000.0             0.0
#
#       worldwide_gross         ROI  Unnamed: 0       genre_ids      id  \
# 2276       41656474.0  415.564740       14362        [27, 53]  299245
# 1816       30087064.0  262.921614       13651            [27]  295154
# 1280       70000000.0  214.384615       23894        [53, 27]  424139
# 2107      101759490.0  100.759490        5444        [53, 27]   76487
# 1489       11000000.0   99.000000       17705            [18]  339408
# ...               ...         ...         ...             ...     ...
# 2039              0.0   -1.000000        6341  [18, 9648, 53]   91316
# 2040              0.0   -1.000000        9939      [53, 9648]  273922
# 2041              0.0   -1.000000        6371     [35, 10749]   98557
# 2042              0.0   -1.000000        8556       [28, 878]  205126
# 1941              0.0   -1.000000       14587        [28, 80]  325173
#
#      original_language            original_title  popularity release_date  \
# 2276                en               The Gallows       9.166   2015-07-10
# 1816                en  Night of the Living Dead       0.600   2014-10-24
# 1280                en                 Halloween      20.839   2018-10-19
# 2107                en          The Devil Inside       7.403   2012-01-06
# 1489                en     The Birth of a Nation       8.152   2016-10-07
# ...                ...                       ...         ...          ...
# 2039                en                  Deadline       1.400   2012-02-15
# 2040                en                  Deadline       0.627   2013-05-16
# 2041                en     Dysfunctional Friends       1.392   2012-02-03
# 2042                en    Independence Daysaster       3.562   2013-06-27
# 1941                en               Close Range       6.604   2015-12-11
#
#                          title  vote_average  vote_count
# 2276               The Gallows           4.8         591
# 1816  Night of the Living Dead           6.5           1
# 1280                 Halloween           6.4        2020
# 2107          The Devil Inside           4.7         441
# 1489     The Birth of a Nation           6.5         328
# ...                        ...           ...         ...
# 2039                  Deadline           5.5           4
# 2040                  Deadline           6.0           1
# 2041     Dysfunctional Friends           5.3           6
# 2042    Independence Daysaster           4.2          35
# 1941               Close Range           5.2          87
#
# [2316 rows x 15 columns]

# %% [markdown]
# ## The Seasonality of Movie ROI: Month-by-Month Breakdown

# %%
# Visualizating the central tendency and spread of ROI values for movies released in each month
movies_budget_merge['release_month'] = pd.to_datetime(movies_budget_merge['release_date']).dt.month

avg_roi_by_month = movies_budget_merge.groupby('release_month')['ROI'].mean()

plt.figure(figsize=(10, 6))
colors = plt.cm.Purples(avg_roi_by_month / max(avg_roi_by_month))
bars = plt.bar(avg_roi_by_month.index, avg_roi_by_month, color=colors)

plt.title('Average ROI by Release Month')
plt.xlabel('Month')
plt.ylabel('Average ROI')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(axis='y', which='both', linestyle='--', linewidth=0.5)
plt.colorbar(plt.cm.ScalarMappable(cmap='Purples'), orientation='vertical', label='ROI Intensity')
plt.tight_layout()
plt.show()

# %%
movies_budget_merge['ROI']
sorted_ROI = movies_budget_merge['ROI'].sort_values(ascending=False)
sorted_ROI.head(30)
# Out:
# 2276    415.564740
# 1816    262.921614
# 1280    214.384615
# 2107    100.759490
# 1489     99.000000
# 1490     99.000000
# 2231     94.576000
# 300      89.893591
# 195      88.586336
# 197      88.586336
# 198      88.586336
# 193      88.586336
# 196      88.586336
# 194      88.586336
# 2088     85.566689
# 2052     65.580591
# 2108     63.364198
# 2185     62.119120
# 2186     62.119120
# 1895     58.170677
# 1719     54.792961
# 1722     54.792961
# 1721     54.792961
# 1720     54.792961
# 1717     50.073590
# 1718     50.073590
# 2053     42.497008
# 2054     42.497008
# 2110     41.411721
# 1723     40.407969
# Name: ROI, dtype: float64

# %%
movies_budget_merge['ROI'].mean()
# Out:
# 3.2682483990100684

# %%
# Density Plot of ROI
roi = movies_budget_merge['ROI']
plt.figure(figsize=(10,6))
sns.kdeplot(roi, shade=True, color='purple')
plt.title('Density Plot of ROI')
plt.xlabel('ROI')
plt.ylabel('Density')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
movies_budget_merge['vote_average'].mean()
# Out:
# 6.206260794473229

# %%
# Distribution of Avarage Votes
vote = movies_budget_merge['vote_average']
plt.figure(figsize=(10,6))
plt.hist(vote, bins=50, color='purple')
plt.title('Distribution of Avarage Votes')
plt.xlabel('Avarege Vote')
plt.ylabel('Number of Movies')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
# Visualisation of the relationship between the ROI and the vote_average to see if there's any correlation between the ratings a movie receives and its return on investment
vote_average = movies_budget_merge['vote_average']
roi = movies_budget_merge['ROI']

plt.figure(figsize=(12, 6))

# Scatter plot
plt.scatter(vote_average, roi, color='purple', alpha=0.5)

plt.title('Scatter Plot of ROI vs Vote Average')
plt.xlabel('Vote Average')
plt.ylabel('ROI')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.tight_layout()
plt.show()

# %%
movies_budget_merge['vote_count'].mean()
# Out:
# 1712.1433506044905

# %%
# Distribution of Counts of votes
count = movies_budget_merge['vote_count']
plt.figure(figsize=(10,6))
plt.hist(count, bins=50, color='purple')
plt.title('Distribution of Counts of votes')
plt.xlabel('Count of votes')
plt.ylabel('Number of Movies')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ## More Data Cleaning

# %% [markdown]
# ### Filtering DataSet

# %%
# Filtering Movies: Ratings Above 7, Votes Exceeding 1,000, and ROI Greater Than 10%
sorted_budgets = movies_budget_genres.sort_values(by = 'ROI', ascending = False)
sorted_budgets = sorted_budgets.sort_values(by = 'ROI', ascending = False)
sorted_budgets = sorted_budgets[(sorted_budgets['averagerating'] > 7) & (sorted_budgets['numvotes'] > 1000) & (sorted_budgets['ROI'] > 10)]
sorted_budgets
# Out:
#        id release_date       movie  production_budget  domestic_gross  \
# 1981   60   2009-04-23        Home           500000.0         15433.0
# 1978   60   2009-04-23        Home           500000.0         15433.0
# 1979   60   2009-04-23        Home           500000.0         15433.0
# 1980   60   2009-04-23        Home           500000.0         15433.0
# 1983   60   2009-04-23        Home           500000.0         15433.0
# ...    ..          ...         ...                ...             ...
# 15460  70   1992-08-07  Unforgiven         14400000.0     101157447.0
# 15455  70   1992-08-07  Unforgiven         14400000.0     101157447.0
# 15459  70   1992-08-07  Unforgiven         14400000.0     101157447.0
# 15462  70   1992-08-07  Unforgiven         14400000.0     101157447.0
# 15461  70   1992-08-07  Unforgiven         14400000.0     101157447.0
#
#        worldwide_gross        ROI primary_title  runtime  \
# 1981        44793168.0  88.586336          Home    127.0
# 1978        44793168.0  88.586336          Home    127.0
# 1979        44793168.0  88.586336          Home    127.0
# 1980        44793168.0  88.586336          Home    127.0
# 1983        44793168.0  88.586336          Home    127.0
# ...                ...        ...           ...      ...
# 15460      159157447.0  10.052600    Unforgiven    135.0
# 15455      159157447.0  10.052600    Unforgiven    135.0
# 15459      159157447.0  10.052600    Unforgiven    135.0
# 15462      159157447.0  10.052600    Unforgiven    135.0
# 15461      159157447.0  10.052600    Unforgiven    135.0
#
#                        genres  averagerating  numvotes           staff_role  \
# 1981                  [Drama]            7.5      1049              actress
# 1978                  [Drama]            7.5      1049             composer
# 1979                  [Drama]            7.5      1049                actor
# 1980                  [Drama]            7.5      1049             director
# 1983                  [Drama]            7.5      1049                actor
# ...                       ...            ...       ...                  ...
# 15460  [Action, Crime, Drama]            7.2      2010                actor
# 15455  [Action, Crime, Drama]            7.2      2010      cinematographer
# 15459  [Action, Crime, Drama]            7.2      2010                actor
# 15462  [Action, Crime, Drama]            7.2      2010              actress
# 15461  [Action, Crime, Drama]            7.2      2010  production_designer
#
#                  staff_name
# 1981   Yekaterina Rednikova
# 1978         Eduard Artemev
# 1979         Sergey Garmash
# 1980           Oleg Pogodin
# 1983          Bogdan Stupka
# ...                     ...
# 15460           Yûya Yagira
# 15455   Norimichi Kasamatsu
# 15459          Ken Watanabe
# 15462        Shioli Kutsuna
# 15461          Ryo Sugimoto
#
# [400 rows x 14 columns]

# %% [markdown]
# ###  Average ROI by Release Month

# %%
# Vizualization: Average ROI by Release Month
import calendar
sorted_budgets['release_month'] = sorted_budgets['release_date'].dt.month.apply(lambda x: calendar.month_name[x])

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

plt.figure(figsize=(20, 10))
bars = sns.barplot(x='release_month', y='ROI', data=sorted_budgets, palette='magma', order=month_order, ci=None)

for bar in bars.patches:
    bars.annotate(format(bar.get_height(), '.1f'), 
                   (bar.get_x() + bar.get_width() / 2., bar.get_height()), 
                   ha='center', va='center',
                   xytext=(0, 9), 
                   textcoords='offset points')

plt.axhline(17, color='royalblue', linestyle='--', label='ROI = 17')

plt.title('Average ROI by Release Month', fontsize=25)
plt.xlabel('Release Month', fontsize=17)
plt.ylabel('Average ROI', fontsize=17)
plt.xticks(rotation=45)
plt.legend()

plt.show()

# %% [markdown]
# ###  Average ROI by Movie Genres

# %%
# Relationship between movie genres and their average ROI values.
exploded_df = sorted_budgets.explode('genres')
genre_roi = exploded_df.groupby('genres')['ROI'].mean().sort_values(ascending=False)

genre_roi = genre_roi.drop('Musical', errors='ignore')

plt.figure(figsize=(12, 6))
colors = sns.color_palette('magma', n_colors=len(genre_roi))
bars = genre_roi.plot(kind='bar', color=colors, alpha=0.7)

for idx, value in enumerate(genre_roi):
    plt.annotate(f'{value:.1f}', 
                 (idx, value), 
                 textcoords="offset points", 
                 xytext=(0,5),  
                 ha='center')  

plt.title('Average ROI by Genre', fontsize=22)
plt.xlabel('Genre', fontsize=20)
plt.ylabel('Average ROI', fontsize=20)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

plt.show()

# %%
# Distribution of Production Budget for Selected Genres
filtered_budgets = sorted_budgets[sorted_budgets['genres'].apply(lambda x: any(genre in x for genre in ['Mystery', 'Horror', 'Thriller', 'Fantasy']))]

melted_budgets = filtered_budgets.explode('genres')
genre_budgets = melted_budgets[melted_budgets['genres'].isin(['Mystery', 'Horror', 'Thriller', 'Fantasy'])]

plt.figure(figsize=(20, 10))
sns_boxplot = sns.boxplot(data=genre_budgets, x='genres', y='production_budget', palette='magma')

plt.title('Distribution of Production Budget for Selected Genres', fontsize=35)
plt.xlabel('Genre', fontsize=28)
plt.ylabel('Production Budget', fontsize=28)
plt.xticks( fontsize=18)
plt.grid(True, which="both", linestyle="--", axis='y')

medians = genre_budgets.groupby('genres')['production_budget'].median()
for idx, label in enumerate(genre_budgets['genres'].unique()):
    plt.annotate(f'${medians[label]:,.0f}', 
                 xy=(idx, medians[label]),
                 xytext=(0,5), 
                 textcoords="offset points",
                 ha='center', 
                 va='center', 
                 color='white',
                 fontsize=15,
                 weight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###  Average ROI by Distribution of Movie Runtimes

# %%
# Histogram with Distribution of Movie Runtimes

plt.figure(figsize=(15, 7))
sns.histplot(data=sorted_budgets, x='runtime', kde=False, bins=30, color='skyblue', edgecolor='black')

plt.title('Distribution of Movie Runtimes', fontsize=20)
plt.xlabel('Runtime (minutes)', fontsize=15)
plt.ylabel('Number of Movies', fontsize=15)
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relationships between Average ROI and Production Budget

# %%
# Displaying the Pearson correlation coefficient and Relationship between Production Budget and ROI > 10%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=sorted_budgets, x='production_budget', y='ROI', alpha=0.5, color='purple')

plt.title('Relationship between Production Budget and ROI > 10%', fontsize=22)
plt.xlabel('Production Budget', fontsize=20)
plt.ylabel('ROI', fontsize=20)
plt.grid(True, which="both", linestyle="--")

correlation = np.corrcoef(sorted_budgets['production_budget'], sorted_budgets['ROI'])[0, 1]
plt.annotate(f'Pearson correlation: {correlation:.2f}', 
             xy=(0.17, 0.95), 
             xycoords='axes fraction', 
             fontsize=12, 
             color='royalblue')

plt.show()

# %%
# Displaying the Pearson correlation coefficient and Relationship between Production Budget and ROI
plt.figure(figsize=(10, 5))
sns.scatterplot(data=movies_budget_merge, x='production_budget', y='ROI', alpha=0.5, color='purple')

plt.title('Relationship between Production Budget and ROI', fontsize=23)
plt.xlabel('Production Budget', fontsize=20)
plt.ylabel('ROI', fontsize=20)
plt.grid(True, which="both", linestyle="--")

correlation = np.corrcoef(movies_budget_merge['production_budget'], movies_budget_merge['ROI'])[0, 1]
plt.annotate(f'Pearson correlation: {correlation:.2f}', 
             xy=(0.17, 0.95), 
             xycoords='axes fraction', 
             fontsize=12, 
             color='royalblue')

plt.show()

# %%
# Displaying Average ROI by Budget Category
bins = [0, 5e6, 20e6, 50e6, 100e6]

labels = ["< 5 million", "5-20 million", "20-50 million", "50-100 million"]

sorted_budgets['budget_category'] = pd.cut(sorted_budgets['production_budget'], bins=bins, labels=labels, include_lowest=True, right=False)

avg_roi = sorted_budgets.groupby('budget_category')['ROI'].mean()

plt.figure(figsize=(12, 6))
bars = sns.barplot(x=avg_roi.index, y=avg_roi.values, palette='magma')

for bar in bars.patches:
    bars.annotate(f'{bar.get_height():.2f}',  # Format with 2 decimal places
                  (bar.get_x() + bar.get_width() / 2., bar.get_height()), 
                  ha='center', va='center',
                  xytext=(0, 9), 
                  textcoords='offset points')

plt.title('Average ROI by Budget Category', fontsize=20)
plt.ylabel('Average ROI', fontsize=16)
plt.xlabel('Budget Category', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Calculating and Sorting Average ROI by Staff Role
sorted_staff = movies_budget_genres.groupby('staff_role')
sorted_staff = sorted_staff['ROI'].mean()
sorted_staff
# Out:
# staff_role
# actor                  2.716018
# actress                3.668201
# archive_footage        1.120821
# archive_sound          1.526178
# cinematographer        3.075224
# composer               3.035291
# director               3.172099
# editor                 3.567231
# producer               3.299064
# production_designer    2.650520
# self                   1.875599
# writer                 2.858757
# Name: ROI, dtype: float64

# %%
# Filtering movies_budget_merge df
sorted_movies = movies_budget_merge.sort_values(by='ROI', ascending=False)
sorted_movies = sorted_movies[(sorted_movies['vote_average'] > 7) & (sorted_movies['vote_count'] > 1000) & (sorted_movies['ROI'] > 10)]
sorted_movies
# Out:
#                                           movie  production_budget  \
# 2088                                        Saw          1200000.0
# 1720                                      Split          5000000.0
# 1718                                    Get Out          5000000.0
# 2053                                  Moonlight          1500000.0
# 2054                                  Moonlight          1500000.0
# 115                        Beauty and the Beast         20000000.0
# 1385                     The Fault in Our Stars         12000000.0
# 1354                                 Black Swan         13000000.0
# 1454                          Good Will Hunting         10000000.0
# 1094                                 La La Land         20000000.0
# 1095                                 La La Land         20000000.0
# 1272                          Beverly Hills Cop         15000000.0
# 748                                          It         35000000.0
# 747                                          It         35000000.0
# 1240                              A Quiet Place         17000000.0
# 1093         Close Encounters of the Third Kind         20000000.0
# 516                           Bohemian Rhapsody         55000000.0
# 1096                              The Conjuring         20000000.0
# 1098                                     Wonder         20000000.0
# 1097                                     Wonder         20000000.0
# 1275                         The Imitation Game         15000000.0
# 869                                      Carrie          1800000.0
# 1823                                    Boyhood          4000000.0
# 1048                                 Green Book         23000000.0
# 505                                    Deadpool         58000000.0
# 1393  Three Billboards Outside Ebbing, Missouri         12000000.0
# 1394  Three Billboards Outside Ebbing, Missouri         12000000.0
# 1396                                       Lion         12000000.0
# 1395                                       Lion         12000000.0
# 377                               The Lion King         79300000.0
# 837                                   Toy Story         30000000.0
# 838                                   Toy Story         30000000.0
# 1738                         Dallas Buyers Club          5000000.0
# 1739                         Dallas Buyers Club          5000000.0
# 1888                                   Whiplash          3300000.0
# 1437                                The Fighter         11000000.0
# 1870                     El secreto de sus ojos          3500000.0
# 1083                    Silver Linings Playbook         21000000.0
#
#       domestic_gross  worldwide_gross        ROI  Unnamed: 0  \
# 2088      55968727.0      103880027.0  85.566689       11055
# 1720     138141585.0      278964806.0  54.792961       17393
# 1718     176040665.0      255367951.0  50.073590       20637
# 2053      27854931.0       65245512.0  42.497008       17447
# 2054      27854931.0       65245512.0  42.497008       20691
# 115      376057266.0      608431132.0  29.421557        5181
# 1385     124872350.0      307166834.0  24.597236       11072
# 1354     106954678.0      331266710.0  24.482055          47
# 1454     138433435.0      225925989.0  21.592599        2485
# 1094     151101803.0      426351163.0  20.317558       17443
# 1095     151101803.0      426351163.0  20.317558       20688
# 1272     234760478.0      316300000.0  20.086667        2510
# 748      327481748.0      697457969.0  18.927371       24005
# 747      327481748.0      697457969.0  18.927371       20729
# 1240     188024361.0      334522294.0  18.677782       23847
# 1093     169100479.0      340800479.0  16.040024       20745
# 516      216303339.0      894985342.0  15.272461       23825
# 1096     137400141.0      318000141.0  14.900007        7895
# 1098     132422809.0      304604712.0  14.230236       23903
# 1097     132422809.0      304604712.0  14.230236       20662
# 1275      91125143.0      227740463.0  14.182698       11026
# 869       25878153.0       25878153.0  13.376752         154
# 1823      25379975.0       57273049.0  13.318262       11138
# 1048      85080171.0      322034439.0  13.001497       23827
# 505      363070709.0      801025593.0  12.810786       17383
# 1393      54513740.0      160191915.0  12.349326       20673
# 1394      54513740.0      160191915.0  12.349326       23922
# 1396      51739495.0      149570720.0  11.464227       20677
# 1395      51739495.0      149570720.0  11.464227       17429
# 377      421785283.0      986214868.0  11.436505        2472
# 837      191796233.0      364545516.0  11.151517           3
# 838      191796233.0      364545516.0  11.151517        2473
# 1738      27298285.0       60611845.0  11.122369        7970
# 1739      27298285.0       60611845.0  11.122369       11112
# 1888      13092006.0       38969037.0  10.808799       11031
# 1437      93617009.0      129262388.0  10.751126         116
# 1870       6391436.0       40527719.0  10.579348          70
# 1083     132092958.0      236412453.0  10.257736        5218
#
#                    genre_ids      id original_language  \
# 2088          [27, 9648, 80]     176                en
# 1720                [27, 53]  381288                en
# 1718          [9648, 53, 27]  419430                en
# 2053                    [18]  376867                en
# 2054                    [18]  376867                en
# 115   [10749, 10751, 16, 14]   10020                en
# 1385             [10749, 18]  222935                en
# 1354                [18, 53]   44214                en
# 1454                    [18]     489                en
# 1094         [35, 18, 10749]  313369                en
# 1095         [35, 18, 10749]  313369                en
# 1272            [28, 35, 80]      90                en
# 748                 [27, 53]  346364                en
# 747                 [27, 53]  346364                en
# 1240       [18, 27, 53, 878]  447332                en
# 1093               [878, 18]     840                en
# 516              [18, 10402]  424694                en
# 1096                [27, 53]  138843                en
# 1098             [18, 10751]  406997                en
# 1097             [18, 10751]  406997                en
# 1275     [36, 18, 53, 10752]  205596                en
# 869                 [27, 53]    7340                en
# 1823                    [18]   85350                en
# 1048                [18, 35]  490132                en
# 505             [28, 12, 35]  293660                en
# 1393                [80, 18]  359940                en
# 1394                [80, 18]  359940                en
# 1396                    [18]  334543                en
# 1395                    [18]  334543                en
# 377          [10751, 16, 18]    8587                en
# 837          [16, 35, 10751]     862                en
# 838          [16, 35, 10751]     862                en
# 1738                [18, 36]  152532                en
# 1739                [18, 36]  152532                en
# 1888             [18, 10402]  244786                en
# 1437                    [18]   45317                en
# 1870   [80, 18, 9648, 10749]   25376                es
# 1083         [18, 35, 10749]   82693                en
#
#                                  original_title  popularity release_date  \
# 2088                                        Saw      19.127   2004-10-29
# 1720                                      Split      25.783   2016-09-26
# 1718                                    Get Out      24.739   2017-02-24
# 2053                                  Moonlight      15.948   2016-10-21
# 2054                                  Moonlight      15.948   2016-10-21
# 115                        Beauty and the Beast      26.701   2012-01-13
# 1385                     The Fault in Our Stars      16.030   2014-05-16
# 1354                                 Black Swan      13.745   2010-12-03
# 1454                          Good Will Hunting      18.013   1997-12-05
# 1094                                 La La Land      16.275   2016-12-09
# 1095                                 La La Land      16.275   2016-12-09
# 1272                          Beverly Hills Cop      15.067   1984-11-30
# 748                                          It      13.966   2017-09-08
# 747                                          It      13.966   2017-09-08
# 1240                              A Quiet Place      29.154   2018-04-06
# 1093         Close Encounters of the Third Kind      13.044   1977-11-16
# 516                           Bohemian Rhapsody      37.197   2018-11-02
# 1096                              The Conjuring      18.886   2013-07-19
# 1098                                     Wonder      20.101   2017-11-17
# 1097                                     Wonder      20.101   2017-11-17
# 1275                         The Imitation Game      33.078   2014-12-19
# 869                                      Carrie       9.467   1976-11-03
# 1823                                    Boyhood      11.141   2014-07-11
# 1048                                 Green Book      36.284   2018-11-16
# 505                                    Deadpool      35.067   2016-02-12
# 1393  Three Billboards Outside Ebbing, Missouri      17.808   2017-11-10
# 1394  Three Billboards Outside Ebbing, Missouri      17.808   2017-11-10
# 1396                                       Lion      17.216   2016-11-25
# 1395                                       Lion      17.216   2016-11-25
# 377                               The Lion King      28.583   1994-06-23
# 837                                   Toy Story      28.005   1995-11-22
# 838                                   Toy Story      28.005   1995-11-22
# 1738                         Dallas Buyers Club      12.389   2013-11-22
# 1739                         Dallas Buyers Club      12.389   2013-11-22
# 1888                                   Whiplash      28.784   2014-10-10
# 1437                                The Fighter      10.395   2010-12-17
# 1870                     El secreto de sus ojos      12.531   2010-04-16
# 1083                    Silver Linings Playbook      15.351   2012-12-25
#
#                                           title  vote_average  vote_count  \
# 2088                                        Saw           7.4        4795
# 1720                                      Split           7.2       10375
# 1718                                    Get Out           7.5        8760
# 2053                                  Moonlight           7.4        3893
# 2054                                  Moonlight           7.4        3893
# 115                        Beauty and the Beast           7.7        5730
# 1385                     The Fault in Our Stars           7.6        7236
# 1354                                 Black Swan           7.6        8374
# 1454                          Good Will Hunting           8.1        5764
# 1094                                 La La Land           7.9       10028
# 1095                                 La La Land           7.9       10028
# 1272                          Beverly Hills Cop           7.1        1827
# 748                                          It           7.2       10931
# 747                                          It           7.2       10931
# 1240                              A Quiet Place           7.3        5848
# 1093         Close Encounters of the Third Kind           7.3        2005
# 516                           Bohemian Rhapsody           8.1        7629
# 1096                              The Conjuring           7.5        5912
# 1098                                     Wonder           8.2        3959
# 1097                                     Wonder           8.2        3959
# 1275                         The Imitation Game           8.1       10396
# 869                                      Carrie           7.1        1766
# 1823                                    Boyhood           7.5        3097
# 1048                                 Green Book           8.3        3499
# 505                                    Deadpool           7.6       20175
# 1393  Three Billboards Outside Ebbing, Missouri           8.2        5432
# 1394  Three Billboards Outside Ebbing, Missouri           8.2        5432
# 1396                                       Lion           8.1        3833
# 1395                                       Lion           8.1        3833
# 377                               The Lion King           8.2       10160
# 837                                   Toy Story           7.9       10174
# 838                                   Toy Story           7.9       10174
# 1738                         Dallas Buyers Club           7.9        4961
# 1739                         Dallas Buyers Club           7.9        4961
# 1888                                   Whiplash           8.4        7908
# 1437                                The Fighter           7.3        2325
# 1870                   The Secret in Their Eyes           7.9        1141
# 1083                    Silver Linings Playbook           7.1        7636
#
#       release_month
# 2088             10
# 1720              9
# 1718              2
# 2053             10
# 2054             10
# 115               1
# 1385              5
# 1354             12
# 1454             12
# 1094             12
# 1095             12
# 1272             11
# 748               9
# 747               9
# 1240              4
# 1093             11
# 516              11
# 1096              7
# 1098             11
# 1097             11
# 1275             12
# 869              11
# 1823              7
# 1048             11
# 505               2
# 1393             11
# 1394             11
# 1396             11
# 1395             11
# 377               6
# 837              11
# 838              11
# 1738             11
# 1739             11
# 1888             10
# 1437             12
# 1870              4
# 1083             12

# %%
# Visualization showing how the number of words in a movie title affects its ROI
sorted_movies['title_word_count'] = sorted_movies['original_title'].apply(lambda x: len(str(x).split()))
avg_roi_by_word_count = sorted_movies.groupby('title_word_count')['ROI'].mean()

plt.figure(figsize=(12, 7))
colors = plt.cm.Purples(avg_roi_by_word_count / max(avg_roi_by_word_count))
bars = plt.bar(avg_roi_by_word_count.index, avg_roi_by_word_count, color=colors)

plt.title('Average ROI by Title Word Count')
plt.xlabel('Number of Words in Title')
plt.ylabel('Average ROI')
plt.grid(axis='y', which='both', linestyle='--', linewidth=0.5)
plt.colorbar(plt.cm.ScalarMappable(cmap='Purples'), orientation='vertical', label='ROI Intensity')
plt.tight_layout()
plt.show()

# %%
# Create a scatter plot to visualize the correlation Between Vote Average and ROI
filtered_movies = sorted_movies[sorted_movies['vote_count'] >= 500]
plt.figure(figsize=(20, 10))
sns.scatterplot(data=filtered_movies, x='vote_count', y='ROI', alpha=0.7, color='royalblue', edgecolor='black')
plt.title('Correlation Between Vote Average and ROI', fontsize=25)
plt.xlabel('Vote Average', fontsize=17)
plt.ylabel('ROI', fontsize=17)
plt.grid(True)
plt.show()

# %%
sorted_by_rating = movie_info.sort_values(by='box_office', ascending=False)
sorted_by_rating.head(20)
# Out:
#         id                                           synopsis rating  \
# 827   1071  This depiction of the last 12 hours in the lif...      R
# 877   1136  The Hobbit: An Unexpected Journey follows titl...  PG-13
# 1188  1525  In Skyfall, Bond's loyalty to M is tested as h...  PG-13
# 690    883  Now that Greg Focker is "in" with his soon-to-...  PG-13
# 1117  1442  Youthful wizard Harry Potter returns to the sc...     PG
# 966   1255  Mission: Impossible III director and Alias cre...  PG-13
# 504    661  One woman's rocky road to the altar gets playe...     PG
# 657    841  This is a contemporary retelling of H.G. Wells...  PG-13
# 1458  1877  A hard-drinking lush finds himself thrust into...  PG-13
# 1237  1600  When a failed assassination attempt occurs on ...  PG-13
# 1331  1722  Former cop Brian O'Conner (Paul Walker) partne...  PG-13
# 1001  1295  "Maleficent" explores the untold story of Disn...     PG
# 1229  1585  A dating doctor claims that with his services ...  PG-13
# 1311  1695  The second chapter in the "Bourne Trilogy," ba...  PG-13
# 1121  1446  In this comedy from Austin Powers director Jay...  PG-13
# 338    443  Marvel's first family of comic superheroes tak...  PG-13
# 1071  1381  When a one-night stand that should have stayed...      R
# 995   1288  A New Jersey rent-a-cop gets his moment to shi...     PG
# 1502  1935  Director Alex Proyas (Dark City, The Crow) hel...  PG-13
# 246    321  Unlimited funds have allowed Diana (McCarthy) ...      R
#
#                          director  \
# 827                    Mel Gibson
# 877                 Peter Jackson
# 1188                   Sam Mendes
# 690                     Jay Roach
# 1117               Chris Columbus
# 966                           nan
# 504                    Joel Zwick
# 657              Steven Spielberg
# 1458                   Peter Berg
# 1237                 Bryan Singer
# 1331                   Justin Lin
# 1001             Robert Stromberg
# 1229  Andrew Tennant|Andy Tennant
# 1311              Paul Greengrass
# 1121                    Jay Roach
# 338                     Tim Story
# 1071                  Judd Apatow
# 995                    Steve Carr
# 1502                  Alex Proyas
# 246                   Seth Gordon
#
#                                                  writer theater_date  \
# 827                      Mel Gibson|Benedict Fitzgerald   2004-02-25
# 877   Peter Jackson|Philippa Boyens|Guillermo del To...   2012-12-14
# 1188                 John Logan|Robert Wade|Neal Purvis   2012-11-09
# 690                           Jim Herzfeld|John Hamburg   2004-12-22
# 1117                                       Steve Kloves   2002-11-15
# 966         Gene Roddenberry|Alex Kurtzman|Roberto Orci   2009-05-07
# 504                                        Nia Vardalos   2002-04-19
# 657                           Josh Friedman|David Koepp   2005-06-29
# 1458     Vincent Gilligan|Vince Gilligan|Vy Vincent Ngo   2008-06-16
# 1237  Daniel Harris|Dan Harris|Michael Dougherty|Bry...   2003-05-02
# 1331                                       Chris Morgan   2011-04-29
# 1001                                   Linda Woolverton   2014-05-30
# 1229                                        Kevin Bisch   2005-02-11
# 1311                                        Tony Gilroy   2004-07-23
# 1121                          John Hamburg|Jim Herzfeld   2000-10-06
# 338             Mark Frost|Michael France|Carl Johansen   2005-07-08
# 1071                                        Judd Apatow   2007-06-01
# 995                              Kevin James|Nick Bakay   2009-01-16
# 1502                         Akiva Goldsman|Jeff Vintar   2004-07-16
# 246                                         Craig Mazin   2013-02-07
#
#           dvd_date currency   box_office  runtime  \
# 827   Aug 31, 2004        $  368000000.0    127.0
# 877   Mar 19, 2013        $  303001229.0    170.0
# 1188  Mar 11, 2013        $  299300000.0    145.0
# 690   Apr 26, 2005        $  279167575.0    118.0
# 1117  Apr 11, 2003        $  261835892.0    161.0
# 966   Nov 17, 2009        $  257704099.0    127.0
# 504   Feb 11, 2003        $  241250669.0     95.0
# 657   Nov 22, 2005        $  234141872.0    117.0
# 1458  Nov 25, 2008        $  227946274.0     92.0
# 1237  Nov 25, 2003        $  214813155.0    134.0
# 1331   Oct 4, 2011        $  209805005.0    131.0
# 1001   Nov 4, 2014        $  190871149.0     97.0
# 1229  Jun 14, 2005        $  177575142.0    120.0
# 1311   Dec 7, 2004        $  176049130.0    108.0
# 1121   Mar 6, 2001        $  164454835.0    108.0
# 338    Dec 6, 2005        $  154485963.0    123.0
# 1071  Sep 25, 2007        $  148734225.0    129.0
# 995   May 19, 2009        $  146336178.0     91.0
# 1502  Dec 14, 2004        $  144738046.0    115.0
# 246    Jun 4, 2013        $  134455175.0    111.0
#
#                                studio  \
# 827              Newmarket Film Group
# 877                      Warner Bros.
# 1188                              MGM
# 690                Universal Pictures
# 1117            Warner Bros. Pictures
# 966                              IMAX
# 504                         IFC Films
# 657                Paramount Pictures
# 1458                Columbia Pictures
# 1237                 20th Century Fox
# 1331               Universal Pictures
# 1001             Walt Disney Pictures
# 1229                    Sony Pictures
# 1311               Universal Pictures
# 1121               Universal Pictures
# 338                  20th Century Fox
# 1071                        Universal
# 995   Sony Pictures/Columbia Pictures
# 1502                 20th Century Fox
# 246                Universal Pictures
#
#                                              genre_list
# 827                                             [Drama]
# 877   [Action and Adventure, Science Fiction and Fan...
# 1188       [Action and Adventure, Mystery and Suspense]
# 690                                            [Comedy]
# 1117     [Kids and Family, Science Fiction and Fantasy]
# 966   [Action and Adventure, Drama, Science Fiction ...
# 504                                   [Comedy, Romance]
# 657   [Action and Adventure, Science Fiction and Fan...
# 1458              [Action and Adventure, Comedy, Drama]
# 1237  [Action and Adventure, Science Fiction and Fan...
# 1331  [Action and Adventure, Drama, Mystery and Susp...
# 1001                      [Science Fiction and Fantasy]
# 1229                                  [Comedy, Romance]
# 1311  [Action and Adventure, Drama, Mystery and Susp...
# 1121                                           [Comedy]
# 338   [Action and Adventure, Science Fiction and Fan...
# 1071                                  [Comedy, Romance]
# 995                                            [Comedy]
# 1502  [Action and Adventure, Mystery and Suspense, S...
# 246                                            [Comedy]

# %%
# Vizualizing Box Office Earnings by Movie Rating
plt.figure(figsize=(12, 6))
sns.barplot(x='rating', y='box_office', data=sorted_by_rating, palette='magma', ci=None)

for bar in plt.gca().patches:
    plt.gca().annotate('{:.0f}'.format(bar.get_height()), 
                       (bar.get_x() + bar.get_width() / 2, bar.get_height()), 
                       ha='center', va='center', 
                       xytext=(0, 5), 
                       textcoords='offset points')

plt.title('Box Office Earnings by Movie Rating')
plt.xlabel('Movie Rating')
plt.ylabel('Box Office Earnings')
plt.tight_layout()
plt.show()

# %%
top_directors = sorted_by_rating['director'].value_counts()
top_directors = top_directors[top_directors.index.notnull()].head(10)
top_directors
# Out:
# director
# nan                41
# Clint Eastwood      4
# Lawrence Kasdan     2
# Neil Jordan         2
# Kasi Lemmons        2
# Seth MacFarlane     2
# Julian Jarrold      2
# Ang Lee             2
# Trish Sie           2
# Donald Petrie       2
# Name: count, dtype: int64

# %%
top_writers = sorted_by_rating['writer'].value_counts()
top_writers = top_writers[top_writers.index.notnull()].head(10)
top_writers
# Out:
# writer
# Edward Burns|Scott Frank                      2
# Peter Morgan                                  2
# Mike White                                    2
# Seth MacFarlane|Alec Sulkin|Wellesley Wild    2
# Mel Gibson|Benedict Fitzgerald                1
# Francis Veber                                 1
# Derek Connolly                                1
# Jane Campion                                  1
# Michael Genet|Rick Famuyiwa                   1
# Hamish McColl|Jimmy Perry                     1
# Name: count, dtype: int64
